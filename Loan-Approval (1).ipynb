# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loan_train = pd.read_csv(r"C:\Users\Administrator\Desktop\Loan_approval.csv")
loan_train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_train.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_train.shape
# Out:
# (614, 13)

# %%
loan_train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan_train.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_train.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
numerical_feature_columns=pd.DataFrame(loan_train._get_numeric_data().columns)
numerical_feature_columns
# Out:
#                    0
# 0    ApplicantIncome
# 1  CoapplicantIncome
# 2         LoanAmount
# 3   Loan_Amount_Term
# 4     Credit_History

# %%
categorical_feature_columns = set(loan_train.columns) - set(loan_train._get_numeric_data().columns)
categorical_feature_columns
# Out:
# {'Dependents',
#  'Education',
#  'Gender',
#  'Loan_ID',
#  'Loan_Status',
#  'Married',
#  'Property_Area',
#  'Self_Employed'}

# %%
loan_train.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_train['Gender']= loan_train['Gender'].fillna(loan_train['Gender'].mode()[0])
loan_train['Dependents']= loan_train['Dependents'].fillna(loan_train['Dependents'].mode()[0])
loan_train['Self_Employed']= loan_train['Self_Employed'].fillna(loan_train['Self_Employed'].mode()[0])

# %%
loan_train['LoanAmount']= loan_train['LoanAmount'].fillna(loan_train['LoanAmount'].mean())
loan_train['Loan_Amount_Term']= loan_train['Loan_Amount_Term'].fillna(loan_train['Loan_Amount_Term'].mean())
loan_train['Credit_History']= loan_train['Credit_History'].fillna(loan_train['Credit_History'].mean())

# %%
loan_train.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              3
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(x='Education', data=loan_train, palette='RdYlGn')
plt.title('Educational Background', fontsize=20)
plt.xlabel('Education', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(color='r')
plt.yticks(color='r')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(x='Gender', data=loan_train, palette='RdYlGn')
plt.title('Male Vs Female Count', fontsize=20)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(color='r')
plt.yticks(color='r')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(x='Married', data=loan_train, palette='RdYlGn')
plt.title('Marriage Status', fontsize=20)
plt.xlabel('Married', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(color='r')
plt.yticks(color='r')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(x='Dependents', data=loan_train)
plt.title('Number of Dependents', fontsize=20)
plt.xlabel('Dependents', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(color='r')
plt.yticks(color='r')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(x='Property_Area', data=loan_train)
plt.title('Mortage Area', fontsize=20)
plt.xlabel('Property_Area', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(color='r')
plt.yticks(color='r')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(x='Self_Employed', data=loan_train)
plt.title('Employment', fontsize=20)
plt.xlabel('Self_Employed', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.xticks(color='r')
plt.yticks(color='r')
plt.show()

# %%
# Encode categorical variables
loan_train_encoded = pd.get_dummies(loan_train)

# Plot correlation matrix
plt.figure(figsize=(10,6))
sns.heatmap(loan_train_encoded.corr(), cmap='gist_ncar')
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,8))
plt.scatter(x=loan_train['Loan_Amount_Term'], y=loan_train['ApplicantIncome'], color='r', marker='o', label='Data Points')
plt.xlabel('Loan Amount Term (months)', fontsize=15)
plt.ylabel("Applicant's Income", fontsize=15)
plt.title('Applicant Income vs Loan Amount Term', fontsize=20)
plt.grid(True)
plt.legend()
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,8))
x= loan_train['LoanAmount']
y = loan_train['Loan_Amount_Term']
plt.xlabel('Loan Amount')
plt.ylabel('Term in months')
plt.scatter(x,y, color = 'r', marker ='o')

# %%
sns.scatterplot(x='ApplicantIncome', y='CoapplicantIncome', data=loan_train)
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='CoapplicantIncome'>

# %%
sns.jointplot(x='ApplicantIncome', y='CoapplicantIncome', data=loan_train, kind='scatter')

# %%
sns.jointplot(x='ApplicantIncome', y='CoapplicantIncome', data=loan_train, kind='reg')

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Gender', y='LoanAmount', data=loan_train, palette='Set2')
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Loan Amount', fontsize=15)
plt.title('Loan Amount Distribution by Gender', fontsize=20)
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Education', y='LoanAmount', data=loan_train)
plt.xlabel('Education', fontsize=15)
plt.ylabel('Loan Amount', fontsize=15)
plt.title('Loan Amount Distribution by Education', fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Property_Area', y='LoanAmount', data=loan_train)
plt.xlabel('Property Area', fontsize=15)
plt.ylabel('Loan Amount', fontsize=15)
plt.title('Loan Amount Distribution by Property Area', fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Self_Employed', y='LoanAmount', data=loan_train)
plt.xlabel('Self Employed', fontsize=15)
plt.ylabel('Loan Amount', fontsize=15)
plt.title('Loan Amount Distribution by Self Employed', fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Married', y='LoanAmount', data=loan_train)
plt.xlabel('Married', fontsize=15)
plt.ylabel('Loan Amount', fontsize=15)
plt.title('Loan Amount Distribution by Marriage Status', fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Dependents', y='LoanAmount', data=loan_train)
plt.xlabel('Dependents', fontsize=15)
plt.ylabel('Loan Amount', fontsize=15)
plt.title('Loan Amount Distribution by Number of Dependents', fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
crosstab = pd.crosstab(index=loan_train['Property_Area'], columns=loan_train['Dependents'])
crosstab
# Out:
# Dependents       0   1   2  3+
# Property_Area
# Rural          111  21  29  18
# Semiurban      136  40  37  20
# Urban          113  41  35  13

# %%
lc = pd.crosstab(loan_train['Credit_History'], loan_train['Loan_Status'])
lc.plot(kind='bar', stacked=True, color=['red','blue'], grid=False)
# Out:
# <Axes: xlabel='Credit_History'>

# %%
sns.histplot(loan_train['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>

# %%
sns.histplot(loan_train['CoapplicantIncome'])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Count'>

# %%
loan_train.plot(figsize=(16,10))
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.grid('darkgrid')
plt.scatter(loan_train['ApplicantIncome'] , loan_train['LoanAmount'], c='r', marker='x')
plt.title("Income vs Loan Amount", fontsize = 15)
plt.xlabel("Applicant's Income", fontsize = 13)
plt.ylabel("Loan Amount", fontsize = 13)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
import warnings

# Suppress warning
warnings.filterwarnings("ignore")

sns.displot(loan_train['Loan_Amount_Term'], color='r', alpha=0.6)
plt.show()

# %%
sns.displot(loan_train['Credit_History'], color='r', alpha=0.6)
plt.show()

# %%
sns.pairplot(loan_train)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Property_Area', y='ApplicantIncome', hue='Loan_Status', data=loan_train)
plt.title('Applicant Income Distribution by Property Area and Loan Status', fontsize=16)
plt.xlabel('Property Area', fontsize=14)
plt.ylabel('Applicant Income', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Loan Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Dependents', y='ApplicantIncome', hue='Education', data=loan_train)
plt.title('Applicant Income Distribution by Dependents and Education', fontsize=16)
plt.xlabel('Dependents', fontsize=14)
plt.ylabel('Applicant Income', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Education', loc='upper right')
plt.show()

# %%
loan_train["Loan_Status"].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import LabelEncoder
categorical_column = ['Gender','Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']
le = LabelEncoder()
for i in categorical_column:
    loan_train[i] = le.fit_transform(loan_train[i])
loan_train.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
# Check if "Loan_ID" exists in the columns of the DataFrame
if "Loan_ID" in loan_train.columns:
    # Dropping "Loan_ID" along with "Loan_Status" to create features (x_train)
    x_train = loan_train.drop(["Loan_Status", "Loan_ID"], axis=1)
else:
    # If "Loan_ID" does not exist, drop only "Loan_Status" to create features (x_train)
    x_train = loan_train.drop(["Loan_Status"], axis=1)

# Extracting the target variable
y_train = loan_train["Loan_Status"]

# %%
x_train,x_test,y_train,y_test = train_test_split(xtrain,ytrain,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# Define preprocessing steps for numerical and categorical columns
numeric_features = x_train.select_dtypes(include=['int64', 'float64']).columns
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = x_train.select_dtypes(include=['object']).columns
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Combine preprocessing steps for numerical and categorical columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# Append classifier to preprocessing pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression())])

# Fit the model
clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# Define the pipeline with an imputer and logistic regression
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # You can choose a different strategy if needed
    ('classifier', LogisticRegression())
])

# Fit the pipeline on the training data
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()),
#                 ('classifier', LogisticRegression())])

# %%
try:
    intercept = reg.intercept_
    print("Intercept:", intercept)
except AttributeError as e:
    print("Error accessing intercept:", e)
# Out:
# Error accessing intercept: 'LogisticRegression' object has no attribute 'intercept_'

# %%
from sklearn.impute import SimpleImputer

# Instantiate the imputer with mean strategy
imputer = SimpleImputer(strategy='mean')

# Fit and transform the imputer on your training data
x_train_imputed = imputer.fit_transform(x_train)

# Transform the test data using the fitted imputer
x_test_imputed = imputer.transform(x_test)

# Train the logistic regression model
reg.fit(x_train_imputed, y_train)

# Evaluate the model on the test set
accuracy = round(reg.score(x_test_imputed, y_test) * 100, 2)
print(f"The accuracy of the model on the test set is {accuracy}%")
# Out:
# The accuracy of the model on the test set is 100.0%
